# %%
import sys
import os

sys.path.append(r"C:\Users\jorda\Documents\GitHub\DataMedic\src")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jorda\Documents\GitHub\DataMedic\test

# %%
import os
os.chdir(r"C:\Users\jorda\Documents\GitHub\DataMedic\test")

# %%
sys.path.append(r"C:\Users\jorda\Documents\GitHub\DataMedic\test")

# %%
import pandas as pd

# %%
from data_getter import DataGetter
from data_doctor import DataDoctor
from data_visualizer import DataVisualizer
from data_exporter import DataExporter
from report_generator import ReportGenerator
from data_pipeline import DataPipeline

# %%
df = pd.read_csv('../datasets/dirty_cafe_sales.csv')
df.head()

doctor = DataDoctor(df)
visualizer = DataVisualizer(df)
exporter = DataExporter(df)
reporter = ReportGenerator(doctor)

# %%
doctor = DataDoctor(df)
visualizer = DataVisualizer(df)
exporter = DataExporter(df)
reporter = ReportGenerator(doctor)

pipeline = DataPipeline(doctor, visualizer, exporter, reporter)
pipeline.run()
# Out:
# === Diagnosing Issues ===
# - Missing values detected. Consider filling or removing them.
#
# === Applying Treatments ===
#
# === Fix Log ===
# - Missing values filled.
# - 0 duplicate rows removed.
# - Outliers handled.
#
# === Visualizing ===
# === Exporting Cleaned Data ===
#
# === Report Generated ===

# %%
from data_inspector import DataInspector

inspector = DataInspector(df)
print(inspector.inspect())
# Out:
# {'missing': Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64, 'duplicates': 0, 'outliers': {}}

# %%
from data_doctor import DataDoctor

from data_getter import DataGetter
from data_doctor import DataDoctor

# Step 1: Load CSV
getter = DataGetter()
df = getter.read_csv("dirty_cafe_sales.csv")

# Step 2: Use DataDoctor
doctor = DataDoctor(df)

# Step 3: Diagnose
print(doctor.diagnose())
# Out:
# Error: 'dirty_cafe_sales.csv' not found.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 14
#      11 doctor = DataDoctor(df)
#      13 # Step 3: Diagnose
# ---> 14 print(doctor.diagnose())
#
# File ~\Documents\GitHub\DataMedic\src\data_doctor.py:11, in DataDoctor.diagnose(self)
#      10 def diagnose(self):
# ---> 11     issues = self.inspect()
#      12     suggestions = []
#      13     if issues['missing'].sum() > 0:
#
# File ~\Documents\GitHub\DataMedic\src\data_inspector.py:11, in DataInspector.inspect(self)
#      10 def inspect(self):
# ---> 11     self._issues['missing'] = self.detect_missing()
#      12     self._issues['duplicates'] = self.detect_duplicates()
#      13     self._issues['outliers'] = self.detect_outliers()
#
# File ~\Documents\GitHub\DataMedic\src\data_inspector.py:17, in DataInspector.detect_missing(self)
# ...

# %%
from data_getter import DataGetter

getter = DataGetter(r"C:\Users\A S P I R E\Documents\GitHub\DataMedic\src")
df = getter.read_csv("dirty_cafe_sales.csv")

print(df.head())  # should now display rows!
# Out:
# Error: 'dirty_cafe_sales.csv' not found.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 6
#       3 getter = DataGetter(r"C:\Users\A S P I R E\Documents\GitHub\DataMedic\src")
#       4 df = getter.read_csv("dirty_cafe_sales.csv")
# ----> 6 print(df.head())
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
getter = DataGetter(r"C:\Users\jorda\Documents\GitHub\DataMedic\datasets")
df = getter.read_csv("dirty_cafe_sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...
